# %%
import base64

# %%
encoded = base64.b64encode(open("/content/drive/MyDrive/모다이브/이미지 링크화/퐁당퐁당_LOVE/1.기본 모드/1.퐁당퐁당LOVE_1회_배경_기우제.jpg", "rb").read())

# %%
print(encoded)
# Out:
# b'...'

# %%
print(f"<img src="data:image/png;base64 {encoded}" />")
# Out:
#   File "/tmp/ipython-input-1545815600.py", line 1
#     print(f"<img src="data:image/png;base64 {encoded}" />")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
b'...'
